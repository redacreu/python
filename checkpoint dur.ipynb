# %%
f = open(" text", 'r', encoding = 'utf-8')

# %% [markdown]
# #

# %%
f.read()
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "code",\n   "execution_count": 60,\n   "id": "8bed8b68",\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "import requests"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 61,\n   "id": "5126906e",\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "from bs4 import BeautifulSoup"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 68,\n   "id": "aa2ac621",\n   "metadata": {},\n   "outputs": [\n    {\n     "name": "stdout",\n     "output_type": "stream",\n     "text": [\n      "Search: France\\n"\n     ]\n    }\n   ],\n   "source": [\n    "Enter_input = input (\\"Search: \\")"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 69,\n   "id": "c2fcfc46",\n   "metadata": {},\n   "outputs": [\n    {\n     "data": {\n      "text/plain": [\n       "\'France\'"\n      ]\n     },\n     "execution_count": 69,\n     "metadata": {},\n     "output_type": "execute_result"\n    }\n   ],\n   "source
# ...

# %%
f.read(12345)
# Out:
# ''

# %%
with open("text.",'w',encoding = 'utf-8') as f:
    nbr_cara=0 
    nbr_mot=0
    f=[fichier.read()]
    for i in f:
                         nbr_cara+=1
                                  
                                  
                                  
    print (nbr_cara,nbr_mot,nbr_ligne)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 4
#       2 nbr_cara=0
#       3 nbr_mot=0
# ----> 4 f=[fichier.read()]
#       5 for i in f:
#       6                      nbr_cara+=1
#
# NameError: name 'fichier' is not defined
